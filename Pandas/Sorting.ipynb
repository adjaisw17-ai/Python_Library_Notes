# %%
people ={ 
      'first': ["Corey","Anand","Ashish" ,"Prateek"],
    'last'  : ["Schafar" ,"Jaiswal","Jaiswal","Rastogi"],
    'email' : ["corey@gmail.com" ,"anand@gmail.com","ashish@gmail.com","rastogi@gmail.com"]
}

# %%
import pandas as pd
df =pd.DataFrame(people)
df
# Out:
#      first     last              email
# 0    Corey  Schafar    corey@gmail.com
# 1    Anand  Jaiswal    anand@gmail.com
# 2   Ashish  Jaiswal   ashish@gmail.com
# 3  Prateek  Rastogi  rastogi@gmail.com

# %%
df.sort_values('last')
# Out:
#      first     last              email
# 1    Anand  Jaiswal    anand@gmail.com
# 2   Ashish  Jaiswal   ashish@gmail.com
# 3  Prateek  Rastogi  rastogi@gmail.com
# 0    Corey  Schafar    corey@gmail.com

# %%
df
# Out:
#      first     last              email
# 0    Corey  Schafar    corey@gmail.com
# 1    Anand  Jaiswal    anand@gmail.com
# 2   Ashish  Jaiswal   ashish@gmail.com
# 3  Prateek  Rastogi  rastogi@gmail.com

# %%
df.sort_values('last',ascending =False)
# Out:
#      first     last              email
# 0    Corey  Schafar    corey@gmail.com
# 3  Prateek  Rastogi  rastogi@gmail.com
# 1    Anand  Jaiswal    anand@gmail.com
# 2   Ashish  Jaiswal   ashish@gmail.com

# %%
df.sort_values(by=['last','first'] ,ascending =False)
# Out:
#      first     last              email
# 0    Corey  Schafar    corey@gmail.com
# 3  Prateek  Rastogi  rastogi@gmail.com
# 2   Ashish  Jaiswal   ashish@gmail.com
# 1    Anand  Jaiswal    anand@gmail.com

# %%
df.sort_values(['last','first'] ,ascending =False)
# Out:
#      first     last              email
# 0    Corey  Schafar    corey@gmail.com
# 3  Prateek  Rastogi  rastogi@gmail.com
# 2   Ashish  Jaiswal   ashish@gmail.com
# 1    Anand  Jaiswal    anand@gmail.com

# %%
df =df.sort_values(['last','first'] ,ascending =[False ,True] )

# %%
df
# Out:
#      first     last              email
# 0    Corey  Schafar    corey@gmail.com
# 3  Prateek  Rastogi  rastogi@gmail.com
# 1    Anand  Jaiswal    anand@gmail.com
# 2   Ashish  Jaiswal   ashish@gmail.com

# %%
df.sort_index()
# Out:
#      first     last              email
# 0    Corey  Schafar    corey@gmail.com
# 1    Anand  Jaiswal    anand@gmail.com
# 2   Ashish  Jaiswal   ashish@gmail.com
# 3  Prateek  Rastogi  rastogi@gmail.com

# %%
df['last'].sort_values()
# Out:
# 1    Jaiswal
# 2    Jaiswal
# 3    Rastogi
# 0    Schafar
# Name: last, dtype: str
